# %% [markdown]
# # Question 1
#
# Given an integer `n`, return *`true` if it is a power of three. Otherwise, return `false`*.
#
# An integer `n` is a power of three, if there exists an integer `x` such that `n == 3x`.
#
# **Example 1:**
#
# **Input**: n = 27
# **Output**: true
# **Explanation**: 27 = 33
#
# **Example 2:**
#
# **Input:** n = 0
# **Output:** false
# **Explanation:** There is no x where 3x = 0.
#
# **Example 3:**
#
# **Input:** n = -1
# **Output:** false
# **Explanation:** There is no x where 3x = (-1).
#
# #### Solution:
# **Algorithm:**
# 1. If `n` is less than or equal to 0, return false.
# 2. While n is divisible by 3, divide `n` by 3.
# 3. If `n` becomes 1 after the division, return true; otherwise, return false.
# **Code:**
# ```python
# def isPowerOfThree(n):
#     if n <= 0:
#         return False
#     while n % 3 == 0:
#         n /= 3
#     return n == 1
# ```
# TC = O(log n) *Since we divide the number by 3 in each iteration until `n` becomes less than or equal to 0.*
#
# SC = O(1)

# %% [markdown]
# # Question 2
#
# You have a list `arr` of all integers in the range `[1, n]` sorted in a strictly increasing order. Apply the following algorithm on `arr`:
#
# - Starting from left to right, remove the first number and every other number afterward until you reach the end of the list.
# - Repeat the previous step again, but this time from right to left, remove the rightmost number and every other number from the remaining numbers.
# - Keep repeating the steps again, alternating left to right and right to left, until a single number remains.
#
# Given the integer `n`, return *the last number that remains in* `arr`.
#
# **Example 1:**
#
# **Input:** n = 9
# **Output:** 6
# **Explanation:**
# arr = [1, 2,3, 4,5, 6,7, 8,9]
# arr = [2,4, 6,8]
# arr = [2, 6]
# arr = [6]
#
# **Example 2:**
#
# **Input:** n = 1
# **Output:** 1
#
# #### Solution:
# **Algorithm:**
# 1. Initialize the range from 1 to n as a list arr.
# 2. Initialize left_to_right as true.
# 3. While the length of arr is greater than 1:
#    - If left_to_right is true, remove every other number starting from index 0.
#    - If left_to_right is false, remove every other number starting from the last index.
#    - Toggle the value of left_to_right.
# 4. Return the remaining number in arr.
# **Code:**
# ```python
# def lastRemaining(n):
#     arr = list(range(1, n+1))
#     left_to_right = True
#     while len(arr) > 1:
#         if left_to_right:
#             arr = arr[::2]
#         else:
#             arr = arr[-2::-2][::-1]
#         left_to_right = not left_to_right
#     return arr[0]
# ```
# TC = O(log n)  *In each iteration, we divide the arrays in equal parts.*
#
# SC = O(1)

# %% [markdown]
# # Question 3
#
# ****Given a set represented as a string, write a recursive code to print all subsets of it. The subsets can be printed in any order.
#
# **Example 1:**
#
# **Input** :  set = “abc”
#
# **Output** : { “”, “a”, “b”, “c”, “ab”, “ac”, “bc”, “abc”}
#
# **Example 2:**
#
# **Input** : set = “abcd”
#
# **Output** : { “”, “a” ,”ab” ,”abc” ,”abcd”, “abd” ,”ac” ,”acd”, “ad” ,”b”, “bc” ,”bcd” ,”bd” ,”c” ,”cd” ,”d” }
#
# #### Solution:
# **Algorithm:**
# 1. Initialize an empty list to store the subsets.
# 2. Define a recursive function generateSubsets that takes three parameters: the current subset, the remaining set, and the index indicating the current position in the set.
# 3. If the index is equal to the length of the set, add the current subset to the list of subsets.
# 4. Otherwise, recursively call the generateSubsets function twice:
#    - First, without including the current element in the subset.
#    - Second, by including the current element in the subset.
# 5. Return the list of subsets.
# **Code:**
# ```python
# def generateSubsets(subset, remaining_set, index):
#     if index == len(remaining_set):
#         subsets.append(subset)
#         return
#     generateSubsets(subset, remaining_set, index + 1)
#     generateSubsets(subset + remaining_set[index], remaining_set, index + 1)
#
# def subsets(s):
#     global subsets
#     subsets = []
#     generateSubsets("", s, 0)
#     return subsets
# ```
# TC = O(2^n)
#
# SC = O(2^n)

# %% [markdown]
# # Question 4
#
# Given a string calculate length of the string using recursion.
#
# **Examples:**
#
# **Input** : str = "abcd"
# **Output** :4
#
# **Input** : str = "GEEKSFORGEEKS"
# **Output** :13
#
# #### Solution;
# **Algorithm:**
# 1. If the input string is empty, return 0.
# 2. Otherwise, recursively calculate the length of the substring excluding the first character and add 1 to it.
# 3. Return the calculated length.
# **Code:**
# ```python
# def calculateLength(s):
#     if s == "":
#         return 0
#     return calculateLength(s[1:]) + 1
#
# # Example 1
# s1 = "abcd"
# print(calculateLength(s1))
# # Output: 4
#
# # Example 2
# s2 = "GEEKSFORGEEKS"
# print(calculateLength(s2))
# # Output: 13
# ```
# TC = O(n)
#
# SC = O(n)

# %% [markdown]
# # Question 5
#
# We are given a string S, we need to find count of all contiguous substrings starting and ending with same character.
#
# **Examples :**
#
# **Input**  : S = "abcab"
# **Output** : 7
# There are 15 substrings of "abcab"
# a, ab, abc, abca, abcab, b, bc, bca
# bcab, c, ca, cab, a, ab, b
# Out of the above substrings, there
# are 7 substrings : a, abca, b, bcab,
# c, a and b.
#
# **Input**  : S = "aba"
# **Output** : 4
# The substrings are a, b, a and aba
# #### Solution:
# **Algorithm:**
# 1. Initialize a variable count to 0 to keep track of the count of substrings.
# 2. Iterate over each character in the string S.
# 3. For each character at index i, consider it as the starting character of a substring. Increment the count by 1.
# 4. Extend the substring by considering each character from i+1 to the end of the string S.
# 5. For each extended substring, if the first and last characters are the same, increment the count by 1.
# 6. After iterating over all characters, return the count.
# **Code:**
# ```python
# def countContiguousSubstrings(S):
#     count = 0
#     n = len(S)
#
#     for i in range(n):
#         count += 1
#
#         for j in range(i+1, n):
#             if S[i] == S[j]:
#                 count += 1
#
#     return count
#
# # Example usage:
# S = "abcab"
# print(countContiguousSubstrings(S))
# # Output: 7
#
# S = "aba"
# print(countContiguousSubstrings(S))
# # Output: 4
# ```
# TC = O(n^2) *We iterate over the remaining characters to check for substrings starting and ending with the same character.*
#
# SC = O(1)

# %% [markdown]
# # Question 6
#
# The [tower of Hanoi](https://en.wikipedia.org/wiki/Tower_of_Hanoi) is a famous puzzle where we have three rods and **N** disks. The objective of the puzzle is to move the entire stack to another rod. You are given the number of discs **N**. Initially, these discs are in the rod 1. You need to print all the steps of discs movement so that all the discs reach the 3rd rod. Also, you need to find the total moves.**Note:** The discs are arranged such that the **top disc is numbered 1** and the **bottom-most disc is numbered N**. Also, all the discs have **different sizes** and a bigger disc **cannot** be put on the top of a smaller disc. Refer the provided link to get a better clarity about the puzzle.
#
# **Example 1:**
# **Input:**
# N = 2
# **Output:**
# move disk 1 from rod 1 to rod 2
# move disk 2 from rod 1 to rod 3
# move disk 1 from rod 2 to rod 3
# 3
# **Explanation:** For N=2 , steps will be
# as follows in the example and total
# 3 steps will be taken.
#
# **Example 2:**
# **Input:**
# N = 3
# **Output:**
# move disk 1 from rod 1 to rod 3
# move disk 2 from rod 1 to rod 2
# move disk 1 from rod 3 to rod 2
# move disk 3 from rod 1 to rod 3
# move disk 1 from rod 2 to rod 1
# move disk 2 from rod 2 to rod 3
# move disk 1 from rod 1 to rod 3
# 7
# **Explanation:** For N=3 , steps will be
# as follows in the example and total
# 7 steps will be taken.
# #### Solution:
# **Algorithm:**
# 1. If the number of discs n is 1:
# - Move the disc from the source rod to the destination rod.
# - Print the step of disc movement.
# - Return 1 (as a single move is made).
#
# 2. Otherwise, follow these steps:
# - Move n-1 discs from the source rod to the auxiliary rod using the destination rod as an intermediate.
# - Move the nth disc from the source rod to the destination rod.
# - Print the step of disc movement.
# - Move the n-1 discs from the auxiliary rod to the destination rod using the source rod as an intermediate.
# **Code:**
# ```python
# def tower_of_hanoi(n, source, auxiliary, destination):
#     if n == 1:
#         print("move disk 1 from rod", source, "to rod", destination)
#         return 1
#     moves = tower_of_hanoi(n-1, source, destination, auxiliary)
#     print("move disk", n, "from rod", source, "to rod", destination)
#     moves += 1
#     moves += tower_of_hanoi(n-1, auxiliary, source, destination)
#     return moves
# # Example usage
# n = 3
# total_moves = tower_of_hanoi(n, 1, 2, 3)
# print("Total moves:", total_moves)
# ```
#
# TC = O(2^n)
#
# SC = O(n)

# %% [markdown]
# # Question 7
#
# Given a string **str**, the task is to print all the permutations of **str**. A **permutation** is an arrangement of all or part of a set of objects, with regard to the order of the arrangement. For instance, the words ‘bat’ and ‘tab’ represents two distinct permutation (or arrangements) of a similar three letter word.
#
# **Examples:**
#
# **Input:** str = “cd”
#
# **Output:** cd dc
#
# **Input:** str = “abb”
#
# **Output:** abb abb bab bba bab bba
# #### Solution:
# **Algorithm:**
# 1. Initialize an empty list permutations to store all the permutations.
# 2. Create a recursive function generatePermutations(current, remaining):
#    - If remaining is empty:
#      - Append current to permutations.
#      - Return.
#    - For each character c in remaining:
#      - Remove c from remaining to get a new string newRemaining.
#      - Call generatePermutations(current + c, newRemaining) recursively.
# 3. Call the recursive function generatePermutations("", str).
# 4. Print all the permutations from the permutations list.
# **Code:**
# ```python
# def printPermutations(str):
#     permutations = []
#
#     def generatePermutations(current, remaining):
#         if len(remaining) == 0:
#             permutations.append(current)
#             return
#
#         for i in range(len(remaining)):
#             c = remaining[i]
#             newRemaining = remaining[:i] + remaining[i+1:]
#             generatePermutations(current + c, newRemaining)
#
#     generatePermutations("", str)
#
#     for permutation in permutations:
#         print(permutation)
#
# # Example usage
# input_str = "abc"
# printPermutations(input_str)
# ```
# TC = O(n!)
#
# SC = O(n^2)

# %% [markdown]
# # Question 8
#
# Given a string, count total number of consonants in it. A consonant is an English alphabet character that is not vowel (a, e, i, o and u). Examples of constants are b, c, d, f, and g.
#
# **Examples :**
#
# **Input** : abc de
# **Output** : 3
# There are three consonants b, c and d.
#
# **Input** : geeksforgeeks portal
# **Output** : 12
#
# #### Solution:
# **Algorithm:**
# 1. Initialize a variable count to 0 to keep track of the consonant count.
# 2. Convert the input string to lowercase to handle both uppercase and lowercase consonants.
# 3. Iterate over each character ch in the string:
#    - If ch is an alphabet character and not a vowel (i.e., not 'a', 'e', 'i', 'o', or 'u'), increment count by 1.
# 4. After iterating through all characters, count will contain the total number of consonants in the string.
# 5. Return count as the output.
# **Code:**
# ```python
# def countConsonants(string):
#     count = 0
#     vowels = ['a', 'e', 'i', 'o', 'u']
#     string = string.lower()
#
#     for ch in string:
#         if ch.isalpha() and ch not in vowels:
#             count += 1
#
#     return count
#
# # Example usage
# input_str = "geeksforgeeks portal"
# consonant_count = countConsonants(input_str)
# print(consonant_count)
# ```
# TC = O(n)
#
# SC = O(1)
